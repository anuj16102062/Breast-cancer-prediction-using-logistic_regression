# %% [markdown]
# # machine-learning-logis
#
# Use the "Run" button to execute the code.

# %%
# !pip install scikit-learn --upgrade --quiet

# %%
# !pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

# %%
od.version()
# Out:
# '0.1.22'

# %%
dataset_url = 'https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data'

# %%
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: anujkumarpandey
# Your Kaggle Key: ········
# ...
# 100%|██████████| 48.6k/48.6k [00:00<00:00, 45.1MB/s]

# %%
import os

# %%
data_dir = './breast-cancer-wisconsin-data'

# %%
os.listdir(data_dir)
# Out:
# ['data.csv']

# %%
train_csv = data_dir + '/data.csv'

# %%
# !pip install pandas --quiet

# %%
import pandas as pd

# %%
raw_df = pd.read_csv(train_csv)

# %% [raw]
# raw_df

# %%
raw_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
raw_df = raw_df.drop('id',axis=1)

# %%
raw_df = raw_df.drop('Unnamed: 32',axis=1)

# %%
raw_df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
input_cols = list(raw_df.columns)[1:]

# %%
len(input_cols)
# Out:
# 30

# %%
target_col=raw_df['diagnosis']

# %%
target_col
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x=raw_df.loc[:,raw_df.columns!='diagnosis']

# %%
y=raw_df['diagnosis']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=55)

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 446        17.75         28.03          117.30      981.6          0.09997
# 523        13.71         18.68           88.73      571.0          0.09916
# 530        11.75         17.56           75.89      422.9          0.10730
# 353        15.08         25.74           98.00      716.6          0.10240
# 173        11.08         14.71           70.21      372.7          0.10060
# ..           ...           ...             ...        ...              ...
# 27         18.61         20.25          122.10     1094.0          0.09440
# 39         13.48         20.82           88.40      559.2          0.10160
# 286        11.94         20.76           77.87      441.0          0.08605
# 164        23.27         22.04          152.10     1686.0          0.08439
# 48         12.05         14.63           78.04      449.3          0.10310
#
# ...

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 366        20.20         26.83          133.70     1234.0          0.09905
# 270        14.29         16.82           90.30      632.6          0.06429
# 268        12.87         16.21           82.38      512.2          0.09425
# 533        20.47         20.67          134.70     1299.0          0.09156
# 481        13.90         19.24           88.73      602.9          0.07991
# ..           ...           ...             ...        ...              ...
# 347        14.76         14.74           94.87      668.7          0.08875
# 37         13.03         18.42           82.61      523.8          0.08983
# 541        14.47         24.99           95.81      656.4          0.08837
# 295        13.77         13.27           88.06      582.7          0.09198
# 461        27.42         26.27          186.90     2501.0          0.10840
#
# ...

# %%
x_train[:1]
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 366         20.2         26.83           133.7     1234.0          0.09905
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 366            0.1669          0.1641               0.1265         0.1875
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 366                  0.0602  ...         24.19          33.81
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 366            160.0      1671.0            0.1278             0.3416
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 366           0.3703                0.2152          0.3271
#
#      fractal_dimension_worst
# 366                  0.07632
#
# [1 rows x 30 columns]

# %%
x_train[:1].to_dict()
# Out:
# {'radius_mean': {366: 20.2},
#  'texture_mean': {366: 26.83},
#  'perimeter_mean': {366: 133.7},
#  'area_mean': {366: 1234.0},
#  'smoothness_mean': {366: 0.09905},
#  'compactness_mean': {366: 0.1669},
#  'concavity_mean': {366: 0.1641},
#  'concave points_mean': {366: 0.1265},
#  'symmetry_mean': {366: 0.1875},
#  'fractal_dimension_mean': {366: 0.0602},
#  'radius_se': {366: 0.9761},
#  'texture_se': {366: 1.892},
#  'perimeter_se': {366: 7.128},
#  'area_se': {366: 103.6},
#  'smoothness_se': {366: 0.008439},
#  'compactness_se': {366: 0.04674},
#  'concavity_se': {366: 0.05904},
#  'concave points_se': {366: 0.02536},
#  'symmetry_se': {366: 0.0371},
#  'fractal_dimension_se': {366: 0.004286},
#  'radius_worst': {366: 24.19},
#  'texture_worst': {366: 33.81},
#  'perimeter_worst': {366: 160.0},
#  'area_worst': {366: 1671.0},
#  'smoothness_worst': {366: 0.1278},
#  'compactness_worst': {366: 0.3416},
#  'concavity_worst': {366: 0.3703},
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(solver='liblinear')

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
model.score(x_test,y_test)
# Out:
# 0.9473684210526315

# %%
model.score(x_train,y_train)
# Out:
# 0.957286432160804

# %%
model.predict(x_test)
# Out:
# array(['M', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'M',
#        'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B'], dtype=object)

# %%
new_input = {'radius_mean': '2021-06-19',
             'texture_mean': 'Launceston',
             'perimeter_mean': 23.2,
             'area_mean': 33.2,
             'smoothness_mean': 10.2,
             'compactness_mean': 4.2,
             'concavity_mean': np.nan,
             'WindGustDir': 'NNW',
             'WindGustSpeed': 52.0,
             'WindDir9am': 'NW',
             'WindDir3pm': 'NNE',
             'WindSpeed9am': 13.0,
             'WindSpeed3pm': 20.0,
             'Humidity9am': 89.0,
             'Humidity3pm': 58.0,
             'Pressure9am': 1004.8,
             'Pressure3pm': 1001.5,
             'Cloud9am': 8.0,
             'Cloud3pm': 5.0,
             'Temp9am': 25.7,
             'Temp3pm': 33.0,
             'RainToday': 'Yes'}

# %%
{'radius_mean': 20.2,
 'texture_mean': 26.83,
 'perimeter_mean': 133.7,
 'area_mean': 1234.0,
 'smoothness_mean': 0.09905,
 'compactness_mean': 0.1669,
 'concavity_mean': 0.1641,
 'concave points_mean': 0.1265,
 'symmetry_mean': 0.1875,
 'fractal_dimension_mean': {366: 0.0602,
 'radius_se': {366: 0.9761},
 'texture_se': {366: 1.892},
 'perimeter_se': {366: 7.128},
 'area_se': {366: 103.6},
 'smoothness_se': {366: 0.008439},
 'compactness_se': {366: 0.04674},
 'concavity_se': {366: 0.05904},
 'concave points_se': {366: 0.02536},
 'symmetry_se': {366: 0.0371},
 'fractal_dimension_se': {366: 0.004286},
 'radius_worst': {366: 24.19},
 'texture_worst': {366: 33.81},
 'perimeter_worst': {366: 160.0},
 'area_worst': {366: 1671.0},
 'smoothness_worst': {366: 0.1278},
 'compactness_worst': {366: 0.3416},
 'concavity_worst': {366: 0.3703},
 'concave points_worst': {366: 0.2152},
 'symmetry_worst': {366: 0.3271},
 'fractal_dimension_worst': {366: 0.07632}}

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="machine-learning-logis")
# Out:
# [jovian] Updating notebook "meanuj8/machine-learning-logis" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/meanuj8/machine-learning-logis
# 'https://jovian.ai/meanuj8/machine-learning-logis'
